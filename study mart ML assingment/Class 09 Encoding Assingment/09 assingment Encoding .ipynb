# %% [markdown]
# <h1 style="color: red;"> Class 09 :  Encoding Assignment </h1>

# %% [markdown]
# <h1 style="color: #6f4f37; text-shadow: 0px 0px 5px rgba(0, 0, 0, 0.7), 0px 0px 10px rgba(0, 0, 0, 0.5);">
#     Question:
# <h3 style="color: #6f4f37; text-shadow: 0px 0px 5px rgba(0, 0, 0, 0.7), 0px 0px 10px rgba(0, 0, 0, 0.5);">
#     Preprocess the housing dataset by encoding all categorical variables using appropriate techniques.
#     Ensure the final dataset is fully numeric and ready for machine learning analysis.
#     y = from house.csv
# </h3>

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('house.csv')

# %%
df.head(2)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
#
# [2 rows x 81 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# <h1 style="color: lightcoral; font-size: 20px;">Null Value Fillap</h1>

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df.LotFrontage.mean()
# Out:
# 70.04995836802665

# %%
df.LotFrontage.median()
# Out:
# 69.0

# %%
import seaborn as sns
sns.histplot(df.LotFrontage)
# Out:
# <Axes: xlabel='LotFrontage', ylabel='Count'>

# %%
mean =df.LotFrontage.mean()
df.LotFrontage = df.LotFrontage.fillna(mean)
df.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 81, dtype: int64

# %% [markdown]
# <h1 style="color: lightcoral; font-size: 20px;">Copy data to use different types of encoding</h1>

# %%
df1 = df.copy()
df2 = df.copy()
df3 = df.copy()
df4 = df.copy()
df5 = df.copy()
df6 = df.copy()
df7 = df.copy()
df8 = df.copy()
df9 = df.copy()

# %% [markdown]
# <h1 style="color: #00FF9A; font-size: 55px;"> 1. Label Encoding</h1>

# %%
df.nunique().to_frame(name='Unique Values').join(df.dtypes.to_frame(name='Data Type'))
# Out:
#                Unique Values Data Type
# Id                      1460     int64
# MSSubClass                15     int64
# MSZoning                   5    object
# LotFrontage              111   float64
# LotArea                 1073     int64
# ...                      ...       ...
# MoSold                    12     int64
# YrSold                     5     int64
# SaleType                   9    object
# SaleCondition              6    object
# SalePrice                663     int64
#
# [81 rows x 2 columns]

# %% [markdown]
# <h1 style="color: #99FFCC; font-size: 17px;"> </br>Column : MSZoning has  5 unique value and there data type is	object<br> So apply Label Encoding here</h1>

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LE =LabelEncoder()

# %%
 # df1[['SaleCondition', 'YrSold', 'MSZoning']] = df1[['SaleCondition', 'YrSold', 'MSZoning']].apply(lambda col: LE.fit_transform(col))

# %%
df1.MSZoning = LE.fit_transform(df1['MSZoning'])

# %%
#df1.iloc[7:10] #df1.hea() er bodole
df1.MSZoning.unique()
# Out:
# array([3, 4, 0, 1, 2])

# %%
df1.SaleCondition = LE.fit_transform(df1['SaleCondition'])

# %%
df1.SaleCondition.unique()
# Out:
# array([4, 0, 5, 1, 2, 3])

# %%
df1.iloc[1:5] #df1.head(5) er bodole
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1   2          20         3         80.0     9600   Pave   NaN      Reg
# 2   3          60         3         68.0    11250   Pave   NaN      IR1
# 3   4          70         3         60.0     9550   Pave   NaN      IR1
# 4   5          60         3         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 1   2007        WD              4     181500
# 2   2008        WD              4     223500
# 3   2006        WD              0     140000
# ...

# %% [markdown]
# <h1 style="color: #00FF9A; font-size: 55px;"> 2. One Hot Encoding</h1>

# %% [markdown]
# <h1 style="color: #99FFCC; font-size: 17px;"> </br>Column : SaleCondition has  6 unique value and there data type is	object<br> So apply Label Encoding here</h1>

# %%
df2.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
pd.get_dummies(df2['SaleCondition']).head()
# Out:
#    Abnorml  AdjLand  Alloca  Family  Normal  Partial
# 0    False    False   False   False    True    False
# 1    False    False   False   False    True    False
# 2    False    False   False   False    True    False
# 3     True    False   False   False   False    False
# 4    False    False   False   False    True    False

# %%
dummy = pd.get_dummies(df2['SaleCondition'], drop_first=True).head() #dummy var trap

# %%
dummy.head()
# Out:
#    AdjLand  Alloca  Family  Normal  Partial
# 0    False   False   False    True    False
# 1    False   False   False    True    False
# 2    False   False   False    True    False
# 3    False   False   False   False    False
# 4    False   False   False    True    False

# %%
df2.drop('SaleCondition', axis=1, inplace=True)

# %%
df2.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 1         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 2         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 3         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 4         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SalePrice
# ...

# %%
new_df2 = pd.concat([df2, dummy], axis=1)

# %%
new_df2.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... MiscVal MoSold YrSold SaleType SalePrice AdjLand  \
# 0         Lvl    AllPub  ...       0      2   2008       WD    208500   False
# 1         Lvl    AllPub  ...       0      5   2007       WD    181500   False
# 2         Lvl    AllPub  ...       0      9   2008       WD    223500   False
# 3         Lvl    AllPub  ...       0      2   2006       WD    140000   False
# 4         Lvl    AllPub  ...       0     12   2008       WD    250000   False
#
#   Alloca  Family  Normal  Partial
# 0  False   False    True    False
# ...

# %% [markdown]
# <h1 style="color: #00FF9A; font-size: 55px;"> 3.  Binary  Encoding</h1>

# %% [markdown]
# <h1 style="color: #99FFCC; font-size: 17px;"> </br>Column : SaleType has  9 unique value and there data type is	object<br> So apply Label Encoding here</h1>

# %%
df3.head(2)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
#
# [2 rows x 81 columns]

# %%
#!pip uninstall category_encoders -y
#!pip install category_encoders

# %%
import category_encoders as ce

# %%
BE = ce.BinaryEncoder(cols=['SaleType'])
BE
# Out:
# BinaryEncoder(cols=['SaleType'])

# %%
df3_binary_encoded = BE.fit_transform(df3)
df3_binary_encoded.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... MiscFeature MiscVal MoSold YrSold SaleType_0  \
# 0         Lvl    AllPub  ...         NaN       0      2   2008          0
# 1         Lvl    AllPub  ...         NaN       0      5   2007          0
# 2         Lvl    AllPub  ...         NaN       0      9   2008          0
# 3         Lvl    AllPub  ...         NaN       0      2   2006          0
# 4         Lvl    AllPub  ...         NaN       0     12   2008          0
#
#   SaleType_1 SaleType_2  SaleType_3  SaleCondition  SalePrice
# ...
